# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assitant giving out nutrition advice.
    You give consise answers.
    """
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Overall, yes—bananas are healthy in moderation.
#
#     Key points:
#     - Nutrients: good source of potassium (helps blood pressure), vitamin B6, vitamin C, and fiber.
#     - Energy: ~90–110 calories per medium banana; natural sugars provide quick energy.
#     - Fat/protein: low fat; low in protein.
#     - Benefits: supports heart health, digestion, and satiety.
#     - Considerations: portion size if watching sugar/calorie intake; people with kidney disease may need to limit potassium; very ripe bananas have higher sugar content.
#
#     Short answer: healthy, convenient, nutrient-dense snack when eaten as part of a balanced diet.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Bananas are healthy and convenient. They’re:
# - Rich in potassium, vitamin C, vitamin B6, and dietary fiber.
# - A natural source of quick energy (carbs from sugars and starch).
# - Low in fat and calories for a medium fruit (about 100 calories).
#
# Notes:
# - The riper the banana, the more sugar (glucose/fructose).
# - If you have kidney disease or require potassium limits, monitor intake.
# - Great on their own or with yogurt, oats, or peanut butter.

# %% [markdown]
# _Good Job!_
